# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# #Dealing with Missing Data

# %%
x = np.array([1,2,3,4,5])

# %%
x.sum()
# Out:
# 15

# %%
print(x.dtype)
# Out:
# int64

# %%
#Missing Data
x = np.array([1,2,3,'--' ,5])

# %%
print(x.dtype)
# Out:
# <U21

# %%
#Standard way to represent missing data....
x = np.array([1,2,3,None,5])

# %%
x.sum()
#throws error........
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-c6d45b513c2c> in <cell line: 1>()
# ----> 1 x.sum()
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
# ---> 48     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      49
#      50 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %%
# nan -> means here is something but not a number......
x = np.array([1,2,3,np.nan ,5])

# %%
x.sum()
#does not prints right result......
# Out:
# nan

# %%
#need solution..
x_b = np.array([True, True, True, False, True])

# %%
x[x_b].sum()
# Out:
# 11.0

# %%
x[x_b].mean()
# Out:
# 2.75

# %%
#Instead of creating of its own, there is numpy sub-module...
# masked array....

m_x = np.ma.masked_array(x, mask = [0,0,0,1,0])

# %%
m_x.sum()
# Out:
# 11.0

# %%
m_x.mean()
# Out:
# 2.75

# %% [markdown]
# #Dealing with Missing Values

# %%
df = pd.read_csv('rooms.csv')

# %%
df.head()
# Out:
#    Room_Number Num_Students  Department Occupied
# 0        101.0            1  Mechanical        Y
# 1        102.0          NaN       Empty        N
# 2        103.0            3  Electrical        Y
# 3        104.0            2  Mechanical        Y
# 4        105.0          NaN    Chemical        N

# %%
df.dtypes
# Out:
# Room_Number     float64
# Num_Students     object
# Department       object
# Occupied         object
# dtype: object

# %%
# %timeit np.arange(10000, dtype="int").sum()
# Out:
# 11.4 µs ± 3.06 µs per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit np.arange(10000, dtype="object").sum()
# Out:
# 708 µs ± 177 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
df.Room_Number.isnull()
#true means missing values
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# 9    False
# Name: Room_Number, dtype: bool

# %%
# now to find number of times missing value occured.....
df.Room_Number.isnull().sum()
# results 1 missing value.....
# Out:
# 1

# %%
df.isnull()
# Out:
#    Room_Number  Num_Students  Department  Occupied
# 0        False         False       False     False
# 1        False          True       False     False
# 2        False         False       False     False
# 3        False         False       False     False
# 4        False          True       False     False
# 5         True         False       False     False
# 6        False         False       False     False
# 7        False          True       False     False
# 8        False         False       False      True
# 9        False         False       False     False

# %%
df.isnull().sum()
# sums up missing values in dataset....
# Out:
# Room_Number     1
# Num_Students    3
# Department      0
# Occupied        1
# dtype: int64

# %%
missing_values = ["NA", "n/a", "na"]

# %%
df = pd.read_csv("rooms.csv",
                 na_values = missing_values)

# %%
df.isnull()
# Out:
#    Room_Number  Num_Students  Department  Occupied
# 0        False         False       False     False
# 1        False          True       False     False
# 2        False         False       False     False
# 3        False         False       False     False
# 4        False          True       False     False
# 5         True         False       False     False
# 6        False         False       False     False
# 7        False          True       False     False
# 8        False          True       False      True
# 9        False         False       False     False

# %%
df.Num_Students.sum()
# Out:
# 12.0

# %%
df.Num_Students.mean()
# Out:
# 2.0

# %%
missing_values = ["NA", "n/a", "na", "Empty", "--"]

# %%
df = pd.read_csv("rooms.csv",
                 na_values = missing_values)

# %%
df.isnull()
# Out:
#    Room_Number  Num_Students  Department  Occupied
# 0        False         False       False     False
# 1        False          True        True     False
# 2        False         False       False     False
# 3        False         False       False     False
# 4        False          True       False     False
# 5         True         False       False     False
# 6        False         False       False      True
# 7        False          True       False     False
# 8        False          True       False      True
# 9        False         False       False     False

# %%
# uniue () -> gives the list of missing abstracts ....
df.Department.unique()
# Out:
# array(['Mechanical', nan, 'Electrical', 'Chemical', 'Civil', 'CS'],
#       dtype=object)

# %%
df.Occupied.unique()
# Out:
# array(['Y', 'N', nan], dtype=object)

# %%
df.isnull()
# Out:
#    Room_Number  Num_Students  Department  Occupied
# 0        False         False       False     False
# 1        False          True        True     False
# 2        False         False       False     False
# 3        False         False       False     False
# 4        False          True       False     False
# 5         True         False       False     False
# 6        False         False       False      True
# 7        False          True       False     False
# 8        False          True       False      True
# 9        False         False       False     False

# %%
df
# Out:
#    Room_Number  Num_Students  Department Occupied
# 0        101.0           1.0  Mechanical        Y
# 1        102.0           NaN         NaN        N
# 2        103.0           3.0  Electrical        Y
# 3        104.0           2.0  Mechanical        Y
# 4        105.0           NaN    Chemical        N
# 5          NaN           1.0  Electrical        Y
# 6        107.0           3.0       Civil      NaN
# 7        108.0           NaN          CS        Y
# 8        109.0           NaN  Mechanical      NaN
# 9        110.0           2.0          CS        N

# %%
missing_values = ["NA", "n/a", "na", "Empty", "--", "NaN"]

# %%
df = pd.read_csv("rooms.csv",
                 na_values = missing_values)

# %%
df.isnull()
# Out:
#    Room_Number  Num_Students  Department  Occupied
# 0        False         False       False     False
# 1        False          True        True     False
# 2        False         False       False     False
# 3        False         False       False     False
# 4        False          True       False     False
# 5         True         False       False     False
# 6        False         False       False      True
# 7        False          True       False     False
# 8        False          True       False      True
# 9        False         False       False     False

# %%
df
# Out:
#    Room_Number  Num_Students  Department Occupied
# 0        101.0           1.0  Mechanical        Y
# 1        102.0           NaN         NaN        N
# 2        103.0           3.0  Electrical        Y
# 3        104.0           2.0  Mechanical        Y
# 4        105.0           NaN    Chemical        N
# 5          NaN           1.0  Electrical        Y
# 6        107.0           3.0       Civil      NaN
# 7        108.0           NaN          CS        Y
# 8        109.0           NaN  Mechanical      NaN
# 9        110.0           2.0          CS        N

# %%
df.Occupied.fillna("N", inplace=True)

# %%
df
# Out:
#    Room_Number  Num_Students  Department Occupied
# 0        101.0           1.0  Mechanical        Y
# 1        102.0           NaN         NaN        N
# 2        103.0           3.0  Electrical        Y
# 3        104.0           2.0  Mechanical        Y
# 4        105.0           NaN    Chemical        N
# 5          NaN           1.0  Electrical        Y
# 6        107.0           3.0       Civil      NaN
# 7        108.0           NaN          CS        Y
# 8        109.0           NaN  Mechanical      NaN
# 9        110.0           2.0          CS        N

# %%
def covert_to_binary(v):
    if v == "Y":
        return True
    else:
        return False

# %%
df.Occupied = df.Occupied.apply(convert_to_binary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-cf4537d2c9ee> in <cell line: 1>()
# ----> 1 df.Occupied = df.Occupied.apply(convert_to_binary)
#
# NameError: name 'convert_to_binary' is not defined

# %%
df
# Out:
#    Room_Number  Num_Students  Department Occupied
# 0        101.0           1.0  Mechanical        Y
# 1        102.0           NaN         NaN        N
# 2        103.0           3.0  Electrical        Y
# 3        104.0           2.0  Mechanical        Y
# 4        105.0           NaN    Chemical        N
# 5          NaN           1.0  Electrical        Y
# 6        107.0           3.0       Civil      NaN
# 7        108.0           NaN          CS        Y
# 8        109.0           NaN  Mechanical      NaN
# 9        110.0           2.0          CS        N

# %%
df["Dept2"] = df.Department

# %%
df.Department.fillna(method="ffill", inplace =True)
# or
df.Department.fillna(method="pad", inplace =True)

# %%
df
# Out:
#    Room_Number  Num_Students  Department Occupied       Dept2
# 0        101.0           1.0  Mechanical        Y  Mechanical
# 1        102.0           NaN  Mechanical        N         NaN
# 2        103.0           3.0  Electrical        Y  Electrical
# 3        104.0           2.0  Mechanical        Y  Mechanical
# 4        105.0           NaN    Chemical        N    Chemical
# 5          NaN           1.0  Electrical        Y  Electrical
# 6        107.0           3.0       Civil      NaN       Civil
# 7        108.0           NaN          CS        Y          CS
# 8        109.0           NaN  Mechanical      NaN  Mechanical
# 9        110.0           2.0          CS        N          CS

# %%
df.Department.fillna(method="bfill", inplace =True)

# %%
df
# Out:
#    Room_Number  Num_Students  Department Occupied       Dept2
# 0        101.0           1.0  Mechanical        Y  Mechanical
# 1        102.0           NaN  Mechanical        N         NaN
# 2        103.0           3.0  Electrical        Y  Electrical
# 3        104.0           2.0  Mechanical        Y  Mechanical
# 4        105.0           NaN    Chemical        N    Chemical
# 5          NaN           1.0  Electrical        Y  Electrical
# 6        107.0           3.0       Civil      NaN       Civil
# 7        108.0           NaN          CS        Y          CS
# 8        109.0           NaN  Mechanical      NaN  Mechanical
# 9        110.0           2.0          CS        N          CS

# %%
df.Num_Students.fillna(df.Num_Students.median(), inplace = True)

# %%
df
# Out:
#    Room_Number  Num_Students  Department Occupied       Dept2
# 0        101.0           1.0  Mechanical        Y  Mechanical
# 1        102.0           2.0  Mechanical        N         NaN
# 2        103.0           3.0  Electrical        Y  Electrical
# 3        104.0           2.0  Mechanical        Y  Mechanical
# 4        105.0           2.0    Chemical        N    Chemical
# 5          NaN           1.0  Electrical        Y  Electrical
# 6        107.0           3.0       Civil      NaN       Civil
# 7        108.0           2.0          CS        Y          CS
# 8        109.0           2.0  Mechanical      NaN  Mechanical
# 9        110.0           2.0          CS        N          CS

# %%
#interpolate -> fills the missing number within the range of
# number we have ...........
df.Room_Number.interpolate()
# Out:
# 0    101.0
# 1    102.0
# 2    103.0
# 3    104.0
# 4    105.0
# 5    106.0
# 6    107.0
# 7    108.0
# 8    109.0
# 9    110.0
# Name: Room_Number, dtype: float64

# %%
df.Room_Number.interpolate(inplace = True)

# %%
df
# Out:
#    Room_Number  Num_Students  Department Occupied       Dept2
# 0        101.0           1.0  Mechanical        Y  Mechanical
# 1        102.0           2.0  Mechanical        N         NaN
# 2        103.0           3.0  Electrical        Y  Electrical
# 3        104.0           2.0  Mechanical        Y  Mechanical
# 4        105.0           2.0    Chemical        N    Chemical
# 5        106.0           1.0  Electrical        Y  Electrical
# 6        107.0           3.0       Civil      NaN       Civil
# 7        108.0           2.0          CS        Y          CS
# 8        109.0           2.0  Mechanical      NaN  Mechanical
# 9        110.0           2.0          CS        N          CS
